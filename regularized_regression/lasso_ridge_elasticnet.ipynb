# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np

# %%
df= pd.read_csv('HousingData.csv')

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %% [markdown]
# ### Meaning of all the columns:
# | Column Name | Meaning                                                                    |
# | ----------- | -------------------------------------------------------------------------- |
# | **CRIM**    | Per capita **crime rate** by town                                          |
# | **ZN**      | Proportion of **residential land zoned** for lots over 25,000 sq. ft.      |
# | **INDUS**   | Proportion of **non-retail business acres** per town                       |
# | **CHAS**    | **Charles River** dummy variable (= 1 if tract bounds river; 0 otherwise)  |
# | **NOX**     | **Nitric oxides concentration** (parts per 10 million)                     |
# | **RM**      | Average number of **rooms per dwelling**                                   |
# | **AGE**     | Proportion of **owner-occupied units built prior to 1940**                 |
# | **DIS**     | Weighted distances to **five Boston employment centres**                   |
# | **RAD**     | Index of **accessibility to radial highways**                              |
# | **TAX**     | **Full-value property-tax rate** per \$10,000                              |
# | **PTRATIO** | **Pupil-teacher ratio** by town                                            |
# | **B**       | 1000(Bk - 0.63)² where Bk is the proportion of **Black residents** by town |
# | **LSTAT**   | **% lower status of the population**                                       |
# | **MEDV**    | **Median value** of owner-occupied homes in \$1000s (**target variable**)  |

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df[['RAD', 'TAX']] = df[['RAD', 'TAX']].astype('float64')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

plt.figure(figsize=(20, 15))
plotnumber = 1
num_columns = len(df.columns)
rows = (num_columns // 5) + 1

for column in df.columns:
    ax = plt.subplot(rows, 5, plotnumber)
    sns.histplot(df[column], kde=True, ax=ax, color='blue', edgecolor='black')
    
    ax.set_title(column, fontsize=13)
    ax.set_xlabel('')
    ax.set_ylabel('Frequency')
    
    plotnumber += 1

plt.tight_layout()
plt.suptitle('Distribution of Each Feature (Float64 Columns)', fontsize=20, y=1.02)
plt.show()

# %%
# Plotting the price with remaining columns

plt.figure(figsize = (15,15))
plotnumber = 1

for column in df:
    if plotnumber <= 14:
        ax = plt.subplot(3, 5, plotnumber)
        sns.scatterplot(x = df['MEDV'], y = df[column])
        
    plotnumber += 1

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (20, 8))
sns.boxplot(data = df, width = 0.8)
plt.show()

# %% [markdown]
# ## we can see that there are some outliers in the data

# %%
X=df.drop('MEDV', axis=1)
y=df['MEDV']
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled 

from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif['VIF'] = [variance_inflation_factor(X_scaled, i) for i in range(X_scaled.shape[1])]
vif['Feature'] = X.columns

vif
# Out:
#          VIF  Feature
# 0   1.741404     CRIM
# 1   2.321843       ZN
# 2   4.049690    INDUS
# 3   1.069182     CHAS
# 4   4.495772      NOX
# 5   2.107004       RM
# 6   3.173844      AGE
# 7   3.827427      DIS
# 8   6.986683      RAD
# 9   8.651382      TAX
# 10  1.810597  PTRATIO
# 11  1.372310        B
# 12  3.156334    LSTAT

# %%
# tax has high multicollinearity, so we will drop it
X = X.drop('TAX', axis=1)

# %%
fig, ax = plt.subplots(figsize = (10, 8))
sns.heatmap(df.corr(), annot = True, fmt = '1.2f', annot_kws = {'size' : 10}, linewidth = 1)
plt.show()

# %%
corr_matrix = df.corr().abs()  
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
high_corr_pairs = [(column, row, upper.loc[row, column]) 
                   for column in upper.columns 
                   for row in upper.index 
                   if upper.loc[row, column] > 0.8]
for col1, col2, corr in high_corr_pairs:
    print(f"{col1} ↔ {col2} = {corr:.2f}")
# Out:
# TAX ↔ RAD = 0.90

# %% [markdown]
# ## So we have to drop either tax or rad

# %%
import statsmodels.formula.api as smf

# %%
lm = smf.ols('MEDV ~ RAD', data=df).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.174
# Model:                            OLS   Adj. R-squared:                  0.171
# Method:                 Least Squares   F-statistic:                     82.34
# Date:                Mon, 14 Jul 2025   Prob (F-statistic):           5.63e-18
# Time:                        15:00:51   Log-Likelihood:                -1392.9
# No. Observations:                 394   AIC:                             2790.
# Df Residuals:                     392   BIC:                             2798.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     26.5087      0.620     42.730      0.000      25.289      27.728
# ...

# %%
lm = smf.ols('MEDV ~ TAX', data=df).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.259
# Model:                            OLS   Adj. R-squared:                  0.257
# Method:                 Least Squares   F-statistic:                     137.0
# Date:                Mon, 14 Jul 2025   Prob (F-statistic):           2.43e-27
# Time:                        15:00:53   Log-Likelihood:                -1371.4
# No. Observations:                 394   AIC:                             2747.
# Df Residuals:                     392   BIC:                             2755.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     33.5943      1.039     32.340      0.000      31.552      35.637
# ...

# %%
## since r-squared is more in the first model, we will drop RAD

# %%
df.drop('RAD', axis=1, inplace=True)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS    TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  296.0     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  242.0     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  242.0     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  222.0     18.7
# 5  0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622  222.0     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 5  394.12   5.21  28.7

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test) 
lr.score(X_train, y_train)
# Out:
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# ...

# %%
lr.score(X_test, y_test)
# Out:
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# 0.6905175764205995

# %%
def adj_r2(X, y, model):
    r2 = model.score(X, y)
    n = X.shape[0]
    p = X.shape[1]
    adjusted_r2 = 1 - (1 - r2) * (n - 1) / (n - p - 1)
    
    return adjusted_r2

# %%
adj_r2(X_train, y_train, lr), adj_r2(X_test, y_test, lr)
# Out:
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# ...

# %% [markdown]
# Since the adjusted R-squared values for the test data is less , there can be overfitting.
# To stop that we will perform lasso regression

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

lasso_cv = LassoCV(alphas=None,cv=10, max_iter=10000)
lasso_cv.fit(X_train_scaled, y_train)
# Out:
# LassoCV(cv=10, max_iter=10000)

# %%
alpha=lasso_cv.alpha_ #it is the best alpha value found by cross-validation
alpha
lasso=Lasso(alpha=lasso_cv.alpha_)
lasso.fit(X_train_scaled, y_train)
# Out:
# Lasso(alpha=np.float64(0.020476474880755158))

# %%
lasso.score(X_train_scaled, y_train), lasso.score(X_test_scaled, y_test)
# Out:
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# ...

# %%
adj_r2(X_train_scaled, y_train, lasso), adj_r2(X_test, y_test, lasso)
# Out:
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# ...

# %% [markdown]
# ## Now we do ridge regression

# %%
from sklearn.linear_model import Ridge, RidgeCV
alphas=np.random.uniform(0.1, 10, 50)
ridge_cv= RidgeCV(alphas=alphas, cv=10)
ridge_cv.fit(X_train_scaled,y_train)
# Out:
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# ...

# %%
alpha=ridge_cv.alpha_ #it is the best alpha value found by cross-validation
alpha
# Out:
# np.float64(9.880200822351508)

# %%
ridge=Ridge(alpha=ridge_cv.alpha_)
ridge.fit(X_train_scaled, y_train)
# Out:
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# Ridge(alpha=np.float64(9.880200822351508))

# %%
ridge.score(X_train_scaled, y_train), ridge.score(X_test, y_test)
# Out:
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# ...

# %%
adj_r2(X_train, y_train, ridge_cv), adj_r2(X_test, y_test, ridge_cv)
# Out:
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# ...

# %% [markdown]
# ## Finally we do elastic net

# %%
from sklearn.linear_model import ElasticNet, ElasticNetCV

elastic_cv= ElasticNetCV(alphas=None,cv=10, max_iter=10000)
elastic_cv.fit(X_train_scaled, y_train)
# Out:
# ElasticNetCV(cv=10, max_iter=10000)

# %%
alpha=elastic_cv.alpha_ #it is the best alpha value found by cross-validation
alpha
# Out:
# np.float64(0.03097940464976965)

# %%
elastic_cv.l1_ratio_
# Out:
# np.float64(0.5)

# %%
elastic_net= ElasticNet(alpha=elastic_cv.alpha_, l1_ratio=elastic_cv.l1_ratio_)
elastic_net.fit(X_train_scaled, y_train)
# Out:
# ElasticNet(alpha=np.float64(0.03097940464976965), l1_ratio=np.float64(0.5))

# %%
elastic_net.score(X_train_scaled, y_train), elastic_net.score(X_test, y_test)
# Out:
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# ...

# %%
adj_r2(X_train, y_train, elastic_net), adj_r2(X_test, y_test, elastic_net)
# Out:
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: invalid value encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: divide by zero encountered in matmul
#   return X @ coef_ + self.intercept_
# /opt/anaconda3/envs/hetu/lib/python3.13/site-packages/sklearn/linear_model/_base.py:279: RuntimeWarning: overflow encountered in matmul
#   return X @ coef_ + self.intercept_
# ...
